# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl 
import seaborn as sns

# %%
# %matplotlib inline

# %%
datos1 = np.random.randn(100)
datos1
# Out:
# array([ 1.74911814, -1.04379289,  2.59882502, -0.67387611,  0.89720005,
#        -0.55914559, -0.27523982,  0.38187072,  0.78256218, -1.30329713,
#         1.66879296,  0.84450599, -0.78534576,  1.0308767 , -0.5179875 ,
#         0.68019361, -0.68974267, -0.77740832, -0.96198227, -0.19538446,
#         1.0183107 ,  1.59434732, -0.46462966,  1.28307795,  0.04738827,
#        -0.06047353,  1.27699188, -1.69875266, -0.73570477, -0.16920722,
#         0.74110505, -1.7060495 , -0.59277368, -0.45815928, -0.24729774,
#        -0.62938307,  0.09142015,  1.19628488,  3.49108161, -1.29278071,
#         0.93286671, -0.55848127, -0.6168886 , -1.94663564,  0.03234111,
#        -0.53001095,  0.55958123,  1.05558995, -1.06669061, -1.71662053,
#         0.79894357,  1.33737201,  0.954869  ,  0.3588933 , -1.0470296 ,
#         0.28834973, -1.34027792, -0.73742564, -0.90256185,  1.39500854,
#         0.63486828,  1.06454499,  0.62558794, -0.20065179,  1.52004432,
# ...

# %%
mpl.pyplot.hist(datos1)
# Out:
# (array([ 7., 13., 20., 15., 16., 19.,  6.,  2.,  1.,  1.]),
#  array([-1.94663564, -1.40286392, -0.85909219, -0.31532047,  0.22845126,
#          0.77222298,  1.31599471,  1.85976644,  2.40353816,  2.94730989,
#          3.49108161]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(datos1)

# %%
sns.distplot(datos1, color="red")

# %%
mpl.pyplot.hist(datos1, color="green", alpha=0.8)
# Out:
# (array([ 7., 13., 20., 15., 16., 19.,  6.,  2.,  1.,  1.]),
#  array([-1.94663564, -1.40286392, -0.85909219, -0.31532047,  0.22845126,
#          0.77222298,  1.31599471,  1.85976644,  2.40353816,  2.94730989,
#          3.49108161]),
#  <a list of 10 Patch objects>)

# %%
datos2 = np.random.randn(80)
mpl.pyplot.hist(datos2, color="yellow", alpha=0.4
               )
# Out:
# (array([ 2.,  1.,  7., 12., 11., 18., 16.,  8.,  4.,  1.]),
#  array([-2.70029399, -2.20906985, -1.71784572, -1.22662158, -0.73539745,
#         -0.24417331,  0.24705082,  0.73827496,  1.22949909,  1.72072323,
#          2.21194736]),
#  <a list of 10 Patch objects>)

# %%
#así se representan 2 histogramas comparando sus datos
mpl.pyplot.hist(datos1, color="blue", alpha=0.3, bins =20, density =True)
mpl.pyplot.hist(datos2, color="green", alpha=0.3, bins =20, density = True)
# Out:
# (array([0.05089326, 0.05089326, 0.        , 0.05089326, 0.10178653,
#         0.25446632, 0.25446632, 0.35625285, 0.25446632, 0.30535959,
#         0.66161244, 0.25446632, 0.45803938, 0.35625285, 0.15267979,
#         0.25446632, 0.10178653, 0.10178653, 0.        , 0.05089326]),
#  array([-2.70029399e+00, -2.45468192e+00, -2.20906985e+00, -1.96345779e+00,
#         -1.71784572e+00, -1.47223365e+00, -1.22662158e+00, -9.81009515e-01,
#         -7.35397448e-01, -4.89785380e-01, -2.44173313e-01,  1.43875451e-03,
#          2.47050822e-01,  4.92662889e-01,  7.38274957e-01,  9.83887024e-01,
#          1.22949909e+00,  1.47511116e+00,  1.72072323e+00,  1.96633529e+00,
#          2.21194736e+00]),
#  <a list of 20 Patch objects>)
